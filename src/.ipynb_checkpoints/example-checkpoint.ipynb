# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
from gluonts.dataset.util import to_pandas

from gluonts.dataset.common import FileDataset

# %%
train_data = FileDataset("../data/train-dataset", freq="D")
test_data = FileDataset("../data/train-dataset", freq="D")
train_data = list(train_data)
test_data = list(test_data)

# %%
from itertools import islice

for ts in islice(train_data, 10):
    fig, ax = plt.subplots(figsize=(12, 6))

    ts = to_pandas(ts)
    ts.plot()
# Out:
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr

# %%
to_pandas(train_data[8])[-250:].plot()
# Out:
# /home/zyy1999/gluon-ts/src/gluonts/dataset/util.py:138: FutureWarning: Timestamp.freqstr is deprecated and will be removed in a future version.
#   freq = start.freqstr
# <AxesSubplot:>

# %%
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx import Trainer

# %%
deepar = DeepAREstimator(freq="D", prediction_length=10, trainer=Trainer(epochs=30))

# %%
model = deepar.train(train_data)
# Out:
# /home/zyy1999/gluon-ts/src/gluonts/transform/feature.py:365: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   self._freq_base = start.freq.base
# /home/zyy1999/gluon-ts/src/gluonts/transform/split.py:36: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   return _shift_timestamp_helper(ts, ts.freq, offset)
# /home/zyy1999/gluon-ts/src/gluonts/transform/feature.py:408: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   if self._full_range_date_features is not None
# /home/zyy1999/gluon-ts/src/gluonts/transform/feature.py:360: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   assert self._freq_base is None or self._freq_base == start.freq.base, (
#   0%|                                                                          | 0/50 [00:00<?, ?it/s]/home/zyy1999/gluon-ts/src/gluonts/transform/feature.py:360: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   assert self._freq_base is None or self._freq_base == start.freq.base, (
# /home/zyy1999/gluon-ts/src/gluonts/transform/split.py:36: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   return _shift_timestamp_helper(ts, ts.freq, offset)
# /home/zyy1999/gluon-ts/src/gluonts/transform/feature.py:408: FutureWarning: Timestamp.freq is deprecated and will be removed in a future version
#   if self._full_range_date_features is not None
# 100%|████████████████████████████████| 50/50 [00:03<00:00, 15.16it/s, epoch=1/30, avg_epoch_loss=4.76]
# 100%|████████████████████████████████| 50/50 [00:03<00:00, 15.82it/s, epoch=2/30, avg_epoch_loss=4.28]
# 100%|████████████████████████████████| 50/50 [00:03<00:00, 15.55it/s, epoch=3/30, avg_epoch_loss=4.11]
# 100%|████████████████████████████████| 50/50 [00:02<00:00, 17.11it/s, epoch=4/30, avg_epoch_loss=4.14]
# 100%|████████████████████████████████| 50/50 [00:02<00:00, 16.75it/s, epoch=5/30, avg_epoch_loss=4.17]
# 100%|████████████████████████████████| 50/50 [00:02<00:00, 17.19it/s, epoch=6/30, avg_epoch_loss=4.12]
# 100%|████████████████████████████████| 50/50 [00:02<00:00, 16.94it/s, epoch=7/30, avg_epoch_loss=4.16]
# 100%|████████████████████████████████| 50/50 [00:02<00:00, 16.93it/s, epoch=8/30, avg_epoch_loss=4.16]
# 100%|████████████████████████████████| 50/50 [00:03<00:00, 16.65it/s, epoch=9/30, avg_epoch_loss=4.01]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.08it/s, epoch=10/30, avg_epoch_loss=4.09]
# 100%|████████████████████████████████| 50/50 [00:03<00:00, 16.56it/s, epoch=11/30, avg_epoch_loss=4.1]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.09it/s, epoch=12/30, avg_epoch_loss=4.11]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.12it/s, epoch=13/30, avg_epoch_loss=4.12]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.09it/s, epoch=14/30, avg_epoch_loss=4.06]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.56it/s, epoch=15/30, avg_epoch_loss=4.02]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.18it/s, epoch=16/30, avg_epoch_loss=4.07]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 16.74it/s, epoch=17/30, avg_epoch_loss=4.03]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.52it/s, epoch=18/30, avg_epoch_loss=4.06]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 15.93it/s, epoch=19/30, avg_epoch_loss=4.03]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 13.16it/s, epoch=20/30, avg_epoch_loss=4.13]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 14.16it/s, epoch=21/30, avg_epoch_loss=4.02]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.49it/s, epoch=22/30, avg_epoch_loss=4.01]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.40it/s, epoch=23/30, avg_epoch_loss=4.12]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 16.68it/s, epoch=24/30, avg_epoch_loss=4.02]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 16.87it/s, epoch=25/30, avg_epoch_loss=4.07]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.30it/s, epoch=26/30, avg_epoch_loss=4.01]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.12it/s, epoch=27/30, avg_epoch_loss=4.11]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 16.83it/s, epoch=28/30, avg_epoch_loss=4.07]
# 100%|███████████████████████████████| 50/50 [00:02<00:00, 17.18it/s, epoch=29/30, avg_epoch_loss=4.08]
# 100%|███████████████████████████████| 50/50 [00:03<00:00, 16.59it/s, epoch=30/30, avg_epoch_loss=4.11]

# %%
from gluonts.evaluation import make_evaluation_predictions

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=test_data,  # test dataset
    predictor=model,  # predictor
    num_samples=250,  # number of sample paths we want for evaluation
)

# %%
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
ts_entry = tss[8]
forecast_entry = forecasts[8]

# %%
def plot_prob_forecasts(ts_entry, forecast_entry):
    plot_length = 150
    prediction_intervals = (50.0, 90.0)
    legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1]

    fig, ax = plt.subplots(1, 1, figsize=(10, 7))
    ts_entry[-plot_length:].plot(ax=ax)  # plot the time series
    forecast_entry.plot(prediction_intervals=prediction_intervals, color='g')
    plt.grid(which="both")
    plt.legend(legend, loc="upper left")
    plt.show()

# %%
plot_prob_forecasts(ts_entry, forecast_entry)
